# %%
from main.compiling.compilers.AncillaPerCheckCompiler import AncillaPerCheckCompiler
from main.compiling.noise.models.CircuitLevelNoise import CircuitLevelNoise
from main.compiling.syndrome_extraction.extractors.ancilla_per_check.mixed.CxCyCzExtractor import CxCyCzExtractor
from main.codes.tic_tac_toe.HoneycombCode import HoneycombCode
from main.codes.tic_tac_toe.gauge_honeycomb_code import GaugeHoneycombCode
from main.codes.tic_tac_toe.FloquetColourCode import FloquetColourCode
from main.codes.tic_tac_toe.TicTacToeCode import TicTacToeCode
from main.utils.enums import State
from main.building_blocks.pauli import Pauli
from main.building_blocks.pauli.PauliLetter import PauliLetter
import stim
import sinter 
import matplotlib.pyplot as plt
import numpy as np
from beliefmatching import BeliefMatchingSinterDecoder
from main.utils.Colour import Blue, Green, Red


class HoneycombCodeZ(TicTacToeCode):
    """Adaptation of the Honeycomb code where the measurement order has been permuted
    """
    def __init__(self, distance: int):
        tic_tac_toe = [
                (Blue, PauliLetter('Z')),
                (Red, PauliLetter('X')),
                (Green, PauliLetter('Y'))]

        super().__init__(distance, tic_tac_toe)

# load the data.
# seperate running and loading.

# %% [markdown]
# # Help functions

# %%
def calculate_threshold(code_name, distances, observable_index, layer_factor,pers):
    tasks = []
    if code_name == "HoneycombCodeX":
        code = HoneycombCode
    elif code_name == "HoneycombCodeZ":
        code = HoneycombCodeZ
    elif code_name == "GaugeHoneycombCodeX":
        code = GaugeHoneycombCode
    elif code_name == "FloquetColourCodeX":
        code = FloquetColourCode
    

    for d in distances:
        for index, p in enumerate(pers):

            # generate circuit
            if code_name[-1] == 'X':
                circuit = get_X_stim_circuit(code(d), observable_index,layer_factor*d, p)
            elif code_name[-1] == 'Z':
                circuit = get_Z_stim_circuit(code(d), observable_index, layer_factor*d, p)
            tasks.append(sinter.Task(
                    circuit=circuit,
                    
                    #detector_error_model=circuit.detector_error_model(approximate_disjoint_errors=True, ignore_decomposition_failures=True),
                    json_metadata={
                        'code': code_name,
                        'distance': d,
                        'p': p,
                        'layers': layer_factor*d}))

    samples = sinter.collect(
        tasks=tasks,
        hint_num_tasks=len(tasks),
        num_workers=8,
        max_shots=5000,
        max_errors=500,
        decoders=['beliefmatching'],
        custom_decoders={'beliefmatching': BeliefMatchingSinterDecoder()},
        print_progress=True,
        save_resume_filepath=f'./resume/{code_name}_{observable_index}_{layer_factor}_belief_matching.json',)
    return(samples)


def get_X_stim_circuit(code,observable_index,layers,p):
    compiler = AncillaPerCheckCompiler(CircuitLevelNoise(p,p,p,p,p), syndrome_extractor=CxCyCzExtractor())
    data_qubits = code.data_qubits.values()
    data_qubit_initial_states = {qubit: State.Plus for qubit in data_qubits}
    final_measurements = [Pauli(qubit, PauliLetter('X')) for qubit in data_qubits]
    logical_observables = [code.logical_qubits[observable_index].x]#, code.logical_qubits[1].x]
    stim_circuit: stim.Circuit = compiler.compile_to_stim(code,layers=layers,initial_states= data_qubit_initial_states, final_measurements=final_measurements,logical_observables=logical_observables)
    return(stim_circuit)

def get_Z_stim_circuit(code,observable_index,layers,p):
    compiler = AncillaPerCheckCompiler(noise_model=CircuitLevelNoise(p,p,p,p,p), syndrome_extractor=CxCyCzExtractor())
    data_qubits = code.data_qubits.values()
    data_qubit_initial_states = {qubit: State.Zero for qubit in data_qubits}
    final_measurements = [Pauli(qubit, PauliLetter('Z')) for qubit in data_qubits]
    logical_observables = [code.logical_qubits[observable_index].z]
    stim_circuit: stim.Circuit = compiler.compile_to_stim(code,layers=layers,initial_states= data_qubit_initial_states, final_measurements=final_measurements,logical_observables=logical_observables)
    return(stim_circuit)

# %%
circuit = get_X_stim_circuit(HoneycombCode(5), 0,10,0.1)
circuit2 = get_X_stim_circuit(GaugeHoneycombCode(5),0, 5, 0.1)
# Out:
# |████████████████████████████████████████✗︎ (!) 243/213 [114%] in 0.1s (1624.95/s)
# |████████████████████████████████████████✗︎ (!) 483/423 [114%] in 0.3s (1650.53/s)

# %%
def dem_histogram(dem):
    weight_dict = dict()
    total_errors = 0
    for dem_object in dem:
        if dem_object.type == "error":
            detector_ids = set()
            observable_ids = set()
            if len(dem_object.targets_copy()) in weight_dict:
                weight_dict[len(dem_object.targets_copy())] += 1
            else:
                weight_dict[len(dem_object.targets_copy())] = 1
            total_errors += 1
            #for target in dem_object.targets_copy():
            #    print('+1')

    print(weight_dict, total_errors)

dem_histogram(circuit.detector_error_model(decompose_errors=True, approximate_disjoint_errors=True))
dem_histogram(circuit2.detector_error_model(decompose_errors=True, approximate_disjoint_errors=True))
# Out:
# {2: 562, 3: 114, 5: 714, 4: 116, 6: 206, 7: 8, 1: 16} 1736
# {2: 1240, 3: 180, 4: 284, 5: 1726, 6: 302, 1: 8, 7: 4} 3744

# %%
#gauge_hcc_X1_samples = calculate_threshold('GaugeHoneycombCodeX',[4], 1,2,np.linspace(0.001,0.003, 5))
hcc_X1_samples = calculate_threshold('HoneycombCodeX',[12], 1,4,np.linspace(0.001,0.003, 5))

# and save datagauge_hcc_X1_samples = calculate_threshold('GaugeHoneycombCodeX',[4,8,12], 1,2,np.linspace(0.001,0.003, 5))
# Out:
# |████████████████████████████████████████✗︎ (!) 1155/1011 [114%] in 8.4s (138.06/s)                                      ▅▇▇ 456/1011 [45%] in 4s (106.5/s, eta: 5s) 505/1011 [50%] in 5s (110.0/s, eta: 5s)  555/1011 [55%] in 5s (112.2/s, eta: 4s)  ▂▂▄ 595/1011 [59%] in 5s (113.6/s, eta: 4s) ▄▆█ 656/1011 [65%] in 6s (116.5/s, eta: 3s) ▄▂▂ 751/1011 [74%] in 6s (119.5/s, eta: 2s) in 7s (121.4/s, eta: 2s) (129.0/s, eta: 1s) (133.2/s, eta: 0s)                         in 8s (135.9/s, eta: -)  1104/1011 [109%] in 8s (136.9/s, eta: -)
# |████████████████████████████████████████✗︎ (!) 1155/1011 [114%] in 6.8s (169.65/s)                                      ▃▁ 425/1011 [42%] in 4s (115.0/s, eta: 6s)  ▁▃▅ 528/1011 [52%] in 4s (128.1/s, eta: 4s) █▆▄ 664/1011 [66%] in 5s (140.2/s, eta: 3s) (150.2/s, eta: 1s)
# |████████████████████████████████████████✗︎ (!) 1155/1011 [114%] in 5.7s (201.05/s)                                       eta: 6s)  █▆▄ 383/1011 [38%] in 3s (140.1/s, eta: 5s) ▆▄▂ 435/1011 [43%] in 3s (148.5/s, eta: 4s)  ▃▁▃ 527/1011 [52%] in 3s (160.5/s, eta: 3s)  671/1011 [66%] in 4s (177.0/s, eta: 2s) (192.8/s, eta: 1s)  ▃▅▇ 1032/1011 [102%] in 5s (203.8/s, eta: 0s)                                 in 5s (203.5/s, eta: -)
# |████████████████████████████████████████✗︎ (!) 1155/1011 [114%] in 6.0s (191.29/s)                                      157.1/s, eta: 3s) (171.1/s, eta: 1s)  ▂▄▆ 912/1011 [90%] in 5s (175.2/s, eta: 1s)  ▅▇▇ 1019/1011 [101%] in 6s (184.0/s, eta: 0s) ▆█▆ 1061/1011 [105%] in 6s (187.5/s, eta: -)                                 ▇▇▅ 1095/1011 [108%] in 6s (188.2/s, eta: -) (189.8/s, eta: -)
# |████████████████████████████████████████✗︎ (!) 1155/1011 [114%] in 6.4s (179.91/s)                                      011 [35%] in 3s (105.4/s, eta: 9s)                                  ▅▇▇ 695/1011 [69%] in 4s (155.4/s, eta: 2s) (166.3/s, eta: 2s) ▇▅▃ 862/1011 [85%] in 5s (173.4/s, eta: 1s)  ▆▄▂ 887/1011 [88%] in 5s (174.9/s, eta: 1s) 1049/1011 [104%] in 6s (177.1/s, eta: -)  1083/1011 [107%] in 6s (179.0/s, eta: -)  █▆▄ 1103/1011 [109%] in 6s (179.4/s, eta: -) 1140/1011 [113%] in 6s (180.8/s, eta: -)
# Starting workers...
# 5 cases left:
#     beliefmatching processes=1  ~core_mins_left=None    (initializing...) {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=1  ~core_mins_left=None    (initializing...) {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=1  ~core_mins_left=None    (initializing...) {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=1  ~core_mins_left=None    (initializing...) {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=1  ~core_mins_left=None    (initializing...) {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=1  ~core_mins_left=None    (initializing...) {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=1  ~core_mins_left=None    (initializing...) {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=1  ~core_mins_left=None    (initializing...) {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=1  ~core_mins_left=None    shots_left=5000     errors_left=500     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=1  ~core_mins_left=None    (initializing...) {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=1  ~core_mins_left=None    shots_left=5000     errors_left=500     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=1  ~core_mins_left=None    shots_left=5000     errors_left=500     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=1  ~core_mins_left=None    shots_left=5000     errors_left=500     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=1  ~core_mins_left=None    shots_left=5000     errors_left=500     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=1  ~core_mins_left=None    shots_left=5000     errors_left=500     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=3  ~core_mins_left=52      shots_left=4900     errors_left=498     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=1  ~core_mins_left=None    shots_left=5000     errors_left=500     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=1  ~core_mins_left=None    shots_left=5000     errors_left=500     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=1  ~core_mins_left=None    shots_left=5000     errors_left=500     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=1  ~core_mins_left=None    shots_left=5000     errors_left=500     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=3  ~core_mins_left=52      shots_left=4900     errors_left=498     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=1  ~core_mins_left=None    shots_left=5000     errors_left=500     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=1  ~core_mins_left=48      shots_left=4900     errors_left=489     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=2  ~core_mins_left=21      shots_left=4900     errors_left=475     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=1  ~core_mins_left=None    shots_left=5000     errors_left=500     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=3  ~core_mins_left=52      shots_left=4900     errors_left=498     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=1  ~core_mins_left=None    shots_left=5000     errors_left=500     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=2  ~core_mins_left=48      shots_left=4900     errors_left=489     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=2  ~core_mins_left=21      shots_left=4900     errors_left=475     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=3  ~core_mins_left=52      shots_left=4900     errors_left=498     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=1  ~core_mins_left=56      shots_left=4900     errors_left=495     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=2  ~core_mins_left=48      shots_left=4900     errors_left=489     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=2  ~core_mins_left=21      shots_left=4900     errors_left=475     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=3  ~core_mins_left=72      shots_left=4776     errors_left=495     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=1  ~core_mins_left=56      shots_left=4900     errors_left=495     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=2  ~core_mins_left=48      shots_left=4900     errors_left=489     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=2  ~core_mins_left=21      shots_left=4900     errors_left=475     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=4  ~core_mins_left=72      shots_left=4776     errors_left=495     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=1  ~core_mins_left=56      shots_left=4900     errors_left=495     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=1  ~core_mins_left=55      shots_left=4711     errors_left=466     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=2  ~core_mins_left=21      shots_left=4900     errors_left=475     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=5  ~core_mins_left=72      shots_left=4776     errors_left=495     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=1  ~core_mins_left=56      shots_left=4900     errors_left=495     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=1  ~core_mins_left=55      shots_left=4711     errors_left=466     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=1  ~core_mins_left=22      shots_left=4713     errors_left=421     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=6  ~core_mins_left=72      shots_left=4776     errors_left=495     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=1  ~core_mins_left=56      shots_left=4900     errors_left=495     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=1  ~core_mins_left=22      shots_left=4713     errors_left=421     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=7  ~core_mins_left=72      shots_left=4776     errors_left=495     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=1  ~core_mins_left=56      shots_left=4900     errors_left=495     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=72      shots_left=4776     errors_left=495     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=78      shots_left=4588     errors_left=491     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=77      shots_left=4400     errors_left=484     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=76      shots_left=4321     errors_left=481     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=75      shots_left=4188     errors_left=477     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=71      shots_left=4055     errors_left=474     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=68      shots_left=3922     errors_left=472     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=65      shots_left=3789     errors_left=466     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=62      shots_left=3656     errors_left=465     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=61      shots_left=3542     errors_left=460     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=60      shots_left=3423     errors_left=458     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=58      shots_left=3310     errors_left=456     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=57      shots_left=3198     errors_left=453     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=55      shots_left=3083     errors_left=447     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=53      shots_left=2967     errors_left=447     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=51      shots_left=2850     errors_left=445     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=49      shots_left=2732     errors_left=442     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=47      shots_left=2616     errors_left=440     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=45      shots_left=2501     errors_left=437     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=43      shots_left=2387     errors_left=433     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=41      shots_left=2273     errors_left=430     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=39      shots_left=2160     errors_left=429     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=37      shots_left=2046     errors_left=427     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=35      shots_left=1933     errors_left=426     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=33      shots_left=1820     errors_left=425     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=32      shots_left=1707     errors_left=423     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=30      shots_left=1595     errors_left=422     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=28      shots_left=1483     errors_left=419     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=26      shots_left=1371     errors_left=416     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=24      shots_left=1260     errors_left=415     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=22      shots_left=1150     errors_left=410     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=20      shots_left=1039     errors_left=407     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=18      shots_left=929      errors_left=404     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=8  ~core_mins_left=16      shots_left=820      errors_left=404     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=0  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=7  ~core_mins_left=14      shots_left=711      errors_left=404     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=1  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=6  ~core_mins_left=12      shots_left=603      errors_left=400     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=2  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=5  ~core_mins_left=10      shots_left=495      errors_left=397     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=3  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=4  ~core_mins_left=8       shots_left=387      errors_left=395     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=4  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=3  ~core_mins_left=6       shots_left=279      errors_left=391     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=5  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=2  ~core_mins_left=4       shots_left=171      errors_left=391     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=6  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 5 cases left:
#     beliefmatching processes=1  ~core_mins_left=2       shots_left=64       errors_left=391     {code=HoneycombCodeX,distance=12,layers=48,p=0.001}
#     beliefmatching processes=7  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 4 cases left:
#     beliefmatching processes=8  ~core_mins_left=74      shots_left=4725     errors_left=488     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 4 cases left:
#     beliefmatching processes=8  ~core_mins_left=77      shots_left=4596     errors_left=479     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 4 cases left:
#     beliefmatching processes=8  ~core_mins_left=82      shots_left=4467     errors_left=472     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 4 cases left:
#     beliefmatching processes=8  ~core_mins_left=83      shots_left=4338     errors_left=464     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 4 cases left:
#     beliefmatching processes=8  ~core_mins_left=82      shots_left=4209     errors_left=460     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 4 cases left:
#     beliefmatching processes=8  ~core_mins_left=81      shots_left=4080     errors_left=458     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 4 cases left:
#     beliefmatching processes=8  ~core_mins_left=80      shots_left=3951     errors_left=450     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 4 cases left:
#     beliefmatching processes=8  ~core_mins_left=78      shots_left=3822     errors_left=444     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 4 cases left:
#     beliefmatching processes=8  ~core_mins_left=76      shots_left=3693     errors_left=437     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 4 cases left:
#     beliefmatching processes=8  ~core_mins_left=73      shots_left=3573     errors_left=431     {code=HoneycombCodeX,distance=12,layers=48,p=0.0015}
#     beliefmatching processes=0  ~core_mins_left=53      shots_left=4522     errors_left=441     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
# ...
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 3 cases left:
#     beliefmatching processes=8  ~core_mins_left=52      shots_left=4386     errors_left=425     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 3 cases left:
#     beliefmatching processes=8  ~core_mins_left=50      shots_left=4250     errors_left=406     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 3 cases left:
#     beliefmatching processes=8  ~core_mins_left=51      shots_left=4114     errors_left=392     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 3 cases left:
#     beliefmatching processes=8  ~core_mins_left=49      shots_left=3978     errors_left=373     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 3 cases left:
#     beliefmatching processes=8  ~core_mins_left=45      shots_left=3842     errors_left=352     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 3 cases left:
#     beliefmatching processes=8  ~core_mins_left=43      shots_left=3706     errors_left=333     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 3 cases left:
#     beliefmatching processes=8  ~core_mins_left=39      shots_left=3570     errors_left=311     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 3 cases left:
#     beliefmatching processes=8  ~core_mins_left=39      shots_left=3434     errors_left=298     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 3 cases left:
#     beliefmatching processes=8  ~core_mins_left=36      shots_left=3300     errors_left=282     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 3 cases left:
#     beliefmatching processes=8  ~core_mins_left=35      shots_left=3170     errors_left=270     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 3 cases left:
#     beliefmatching processes=8  ~core_mins_left=31      shots_left=3046     errors_left=247     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 3 cases left:
#     beliefmatching processes=8  ~core_mins_left=29      shots_left=2924     errors_left=230     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 3 cases left:
#     beliefmatching processes=8  ~core_mins_left=28      shots_left=2798     errors_left=219     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 3 cases left:
#     beliefmatching processes=8  ~core_mins_left=26      shots_left=2675     errors_left=206     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 3 cases left:
#     beliefmatching processes=8  ~core_mins_left=24      shots_left=2554     errors_left=189     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 3 cases left:
#     beliefmatching processes=8  ~core_mins_left=23      shots_left=2431     errors_left=179     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 3 cases left:
#     beliefmatching processes=8  ~core_mins_left=22      shots_left=2310     errors_left=169     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# 3 cases left:
#     beliefmatching processes=8  ~core_mins_left=20      shots_left=2186     errors_left=154     {code=HoneycombCodeX,distance=12,layers=48,p=0.002}
#     beliefmatching processes=0  ~core_mins_left=18      shots_left=4526     errors_left=358     {code=HoneycombCodeX,distance=12,layers=48,p=0.0025}
#     beliefmatching processes=0  ~core_mins_left=10      shots_left=4900     errors_left=451     {code=HoneycombCodeX,distance=12,layers=48,p=0.003}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/pderks/Documents/phd/floquet_colour_codes_numerics/scripts/generate_data_bm.ipynb Cell 6 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/pderks/Documents/phd/floquet_colour_codes_numerics/scripts/generate_data_bm.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> #gauge_hcc_X1_samples = calculate_threshold('GaugeHoneycombCodeX',[4], 1,2,np.linspace(0.001,0.003, 5))
# ----> <a href='vscode-notebook-cell:/home/pderks/Documents/phd/floquet_colour_codes_numerics/scripts/generate_data_bm.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> hcc_X1_samples = calculate_threshold('HoneycombCodeX',[12], 1,4,np.linspace(0.001,0.003, 5))
#
# /home/pderks/Documents/phd/floquet_colour_codes_numerics/scripts/generate_data_bm.ipynb Cell 6 in calculate_threshold(code_name, distances, observable_index, layer_factor, pers)
#      <a href='vscode-notebook-cell:/home/pderks/Documents/phd/floquet_colour_codes_numerics/scripts/generate_data_bm.ipynb#W5sZmlsZQ%3D%3D?line=19'>20</a>             circuit = get_Z_stim_circuit(code(d), observable_index, layer_factor*d, p)
#      <a href='vscode-notebook-cell:/home/pderks/Documents/phd/floquet_colour_codes_numerics/scripts/generate_data_bm.ipynb#W5sZmlsZQ%3D%3D?line=20'>21</a>         tasks.append(sinter.Task(
#      <a href='vscode-notebook-cell:/home/pderks/Documents/phd/floquet_colour_codes_numerics/scripts/generate_data_bm.ipynb#W5sZmlsZQ%3D%3D?line=21'>22</a>                 circuit=circuit,
#      <a href='vscode-notebook-cell:/home/pderks/Documents/phd/floquet_colour_codes_numerics/scripts/generate_data_bm.ipynb#W5sZmlsZQ%3D%3D?line=22'>23</a>
#    (...)
#      <a href='vscode-notebook-cell:/home/pderks/Documents/phd/floquet_colour_codes_numerics/scripts/generate_data_bm.ipynb#W5sZmlsZQ%3D%3D?line=27'>28</a>                     'p': p,
#      <a href='vscode-notebook-cell:/home/pderks/Documents/phd/floquet_colour_codes_numerics/scripts/generate_data_bm.ipynb#W5sZmlsZQ%3D%3D?line=28'>29</a>                     'layers': layer_factor*d}))
# ---> <a href='vscode-notebook-cell:/home/pderks/Documents/phd/floquet_colour_codes_numerics/scripts/generate_data_bm.ipynb#W5sZmlsZQ%3D%3D?line=30'>31</a> samples = sinter.collect(
#      <a href='vscode-notebook-cell:/home/pderks/Documents/phd/floquet_colour_codes_numerics/scripts/generate_data_bm.ipynb#W5sZmlsZQ%3D%3D?line=31'>32</a>     tasks=tasks,
#      <a href='vscode-notebook-cell:/home/pderks/Documents/phd/floquet_colour_codes_numerics/scripts/generate_data_bm.ipynb#W5sZmlsZQ%3D%3D?line=32'>33</a>     hint_num_tasks=len(tasks),
#      <a href='vscode-notebook-cell:/home/pderks/Documents/phd/floquet_colour_codes_numerics/scripts/generate_data_bm.ipynb#W5sZmlsZQ%3D%3D?line=33'>34</a>     num_workers=8,
#      <a href='vscode-notebook-cell:/home/pderks/Documents/phd/floquet_colour_codes_numerics/scripts/generate_data_bm.ipynb#W5sZmlsZQ%3D%3D?line=34'>35</a>     max_shots=5000,
#      <a href='vscode-notebook-cell:/home/pderks/Documents/phd/floquet_colour_codes_numerics/scripts/generate_data_bm.ipynb#W5sZmlsZQ%3D%3D?line=35'>36</a>     max_errors=500,
#      <a href='vscode-notebook-cell:/home/pderks/Documents/phd/floquet_colour_codes_numerics/scripts/generate_data_bm.ipynb#W5sZmlsZQ%3D%3D?line=36'>37</a>     decoders=['beliefmatching'],
#      <a href='vscode-notebook-cell:/home/pderks/Documents/phd/floquet_colour_codes_numerics/scripts/generate_data_bm.ipynb#W5sZmlsZQ%3D%3D?line=37'>38</a>     custom_decoders={'beliefmatching': BeliefMatchingSinterDecoder()},
#      <a href='vscode-notebook-cell:/home/pderks/Documents/phd/floquet_colour_codes_numerics/scripts/generate_data_bm.ipynb#W5sZmlsZQ%3D%3D?line=38'>39</a>     print_progress=True,
#      <a href='vscode-notebook-cell:/home/pderks/Documents/phd/floquet_colour_codes_numerics/scripts/generate_data_bm.ipynb#W5sZmlsZQ%3D%3D?line=39'>40</a>     save_resume_filepath=f'./resume/{code_name}_{observable_index}_{layer_factor}_belief_matching.json',)
#      <a href='vscode-notebook-cell:/home/pderks/Documents/phd/floquet_colour_codes_numerics/scripts/generate_data_bm.ipynb#W5sZmlsZQ%3D%3D?line=40'>41</a> return(samples)
#
# File ~/anaconda3/envs/fcc_3.9/lib/python3.9/site-packages/sinter/_collection.py:238, in collect(num_workers, tasks, existing_data_filepaths, save_resume_filepath, progress_callback, max_shots, max_errors, decoders, max_batch_seconds, max_batch_size, start_batch_size, print_progress, hint_num_tasks, custom_decoders)
#     236 result = ExistingData()
#     237 result.data = dict(additional_existing_data.data)
# --> 238 for progress in iter_collect(
#     239     num_workers=num_workers,
#     240     max_shots=max_shots,
#     241     max_errors=max_errors,
#     242     max_batch_seconds=max_batch_seconds,
#     243     start_batch_size=start_batch_size,
#     244     max_batch_size=max_batch_size,
#     245     decoders=decoders,
#     246     tasks=tasks,
#     247     hint_num_tasks=hint_num_tasks,
#     248     additional_existing_data=additional_existing_data,
#     249     custom_decoders=custom_decoders,
#     250 ):
#     251     for stats in progress.new_stats:
#     252         result.add_sample(stats)
#
# File ~/anaconda3/envs/fcc_3.9/lib/python3.9/site-packages/sinter/_collection.py:124, in iter_collect(num_workers, tasks, hint_num_tasks, additional_existing_data, max_shots, max_errors, decoders, max_batch_seconds, max_batch_size, start_batch_size, custom_decoders)
#     117 yield Progress(
#     118     new_stats=(),
#     119     status_message=manager.status(num_circuits=hint_num_tasks)
#     120 )
#     122 while manager.fill_work_queue():
#     123     # Wait for a worker to finish a job.
# --> 124     sample = manager.wait_for_next_sample()
#     125     manager.fill_work_queue()
#     127     # Report the incremental results.
#
# File ~/anaconda3/envs/fcc_3.9/lib/python3.9/site-packages/sinter/_collection_work_manager.py:109, in CollectionWorkManager.wait_for_next_sample(self, timeout)
#     105 def wait_for_next_sample(self,
#     106                          *,
#     107                          timeout: Optional[float] = None,
#     108                          ) -> TaskStats:
# --> 109     result = self.queue_from_workers.get(timeout=timeout)
#     110     assert isinstance(result, WorkOut)
#     111     if result.msg_error is not None:
#
# File ~/anaconda3/envs/fcc_3.9/lib/python3.9/multiprocessing/queues.py:103, in Queue.get(self, block, timeout)
#     101 if block and timeout is None:
#     102     with self._rlock:
# --> 103         res = self._recv_bytes()
#     104     self._sem.release()
#     105 else:
#
# File ~/anaconda3/envs/fcc_3.9/lib/python3.9/multiprocessing/connection.py:221, in _ConnectionBase.recv_bytes(self, maxlength)
#     219 if maxlength is not None and maxlength < 0:
#     220     raise ValueError("negative maxlength")
# --> 221 buf = self._recv_bytes(maxlength)
#     222 if buf is None:
#     223     self._bad_message_length()
#
# File ~/anaconda3/envs/fcc_3.9/lib/python3.9/multiprocessing/connection.py:419, in Connection._recv_bytes(self, maxsize)
#     418 def _recv_bytes(self, maxsize=None):
# --> 419     buf = self._recv(4)
#     420     size, = struct.unpack("!i", buf.getvalue())
#     421     if size == -1:
#
# File ~/anaconda3/envs/fcc_3.9/lib/python3.9/multiprocessing/connection.py:384, in Connection._recv(self, size, read)
#     382 remaining = size
#     383 while remaining > 0:
# --> 384     chunk = read(handle, remaining)
#     385     n = len(chunk)
#     386     if n == 0:
#
# KeyboardInterrupt:
